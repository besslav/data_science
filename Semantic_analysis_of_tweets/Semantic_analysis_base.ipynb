# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('clean_df.csv')
#df['text'] = df['text'].apply(lambda x: x[2:-2].split("', '"))
df['text'] = df['text'].apply(lambda x: x[2:-2].replace("', '", " "))
df
# Out:
#                         id        date             name  \
# 0       408906692374446080  1386325927  pleease_shut_up
# 1       408906692693221377  1386325927  alinakirpicheva
# 2       408906695083954177  1386325927        EvgeshaRe
# 3       408906695356973056  1386325927    ikonnikova_21
# 4       408906761416867842  1386325943        JumpyAlex
# ...                    ...         ...              ...
# 226829  425138243257253888  1390195830         Yanch_96
# 226830  425138339503943682  1390195853          tkit_on
# 226831  425138437684215808  1390195876         ckooker1
# 226832  425138490452344832  1390195889       LisaBeroud
# 226833  425138595251625984  1390195914       sukapavlov
#
#                                                      text  positive  rep  rtv  \
# 0       школотый поверь самый общество профилировать п...         1    0    0
# 1                      таки немного похожий мальчик равно         1    0    0
# 2                                      идиотка испугаться         1    0    1
# 3       угол сидеть погибать голод ещ порция взять хот...         1    0    1
# 4       значит страшилка блин посмотреть часть создать...         1    0    0
# ...                                                   ...       ...  ...  ...
# 226829                           каждый хотеть исправлять         0    0    0
# 226830               скучать вправлять мозг равно скучать         0    0    0
# 226831                               школа говно это идти         0    0    0
# 226832                             тауриэль грусть обнять         0    0    1
# 226833  такси везти работа раздумывать приплатить втащ...         0    0    0
#
#         fav  total_count  fol  friends  list_count
# 0         0         7569   62       61           0
# 1         0        11825   59       31           2
# 2         0         1273   26       27           0
# 3         0         1549   19       17           0
# 4         0          597   16       23           1
# ...     ...          ...  ...      ...         ...
# 226829    0         1138   32       46           0
# 226830    0         4822   38       32           0
# 226831    1          165   13       16           0
# 226832    0         2516  187      265           0
# 226833    0         7778  146       66           5
#
# [226834 rows x 12 columns]

# %%
# разбиение данных на тестовую и обучающую выборку.
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.text, df.positive, test_size=0.2, random_state=21)

# %%
# Для разработки моделей необходимо оцифровать полученные данные.
# Будут использованы два метода: мешок слов CountVectorizer и TF-IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
cv = CountVectorizer()
cv_train = cv.fit_transform(X_train)
cv_test = cv.transform(X_test)

tfidf = TfidfVectorizer()
tfidf_train = tfidf.fit_transform(X_train)
tfidf_test = tfidf.transform(X_test)

# %%
lr = LogisticRegression(random_state=21)
lr.fit(cv_train, y_train)
cv_pred = lr.predict(cv_test)
print('test')
print(classification_report(y_test, cv_pred))
print('train')
print(classification_report(y_train, lr.predict(cv_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71     22361
#            1       0.72      0.73      0.72     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.81      0.80      0.81     89562
#            1       0.81      0.82      0.82     91905
#
#     accuracy                           0.81    181467
#    macro avg       0.81      0.81      0.81    181467
# weighted avg       0.81      0.81      0.81    181467

# %%
lr = LogisticRegression(random_state=21)
lr.fit(tfidf_train, y_train)
tfidf_pred = lr.predict(tfidf_test)
print('test')
print(classification_report(y_test, tfidf_pred))
print('train')
print(classification_report(y_train, lr.predict(tfidf_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71     22361
#            1       0.71      0.75      0.73     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78     89562
#            1       0.78      0.81      0.80     91905
#
#     accuracy                           0.79    181467
#    macro avg       0.79      0.79      0.79    181467
# weighted avg       0.79      0.79      0.79    181467

# %%
# лес очень медленно

# %%
forest = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=21)
forest.fit(cv_train, y_train)
cv_pred = forest.predict(cv_test)
print('test')
print(classification_report(y_test, cv_pred))
print('train')
print(classification_report(y_train, forest.predict(cv_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.72     22361
#            1       0.74      0.64      0.68     23006
#
#     accuracy                           0.70     45367
#    macro avg       0.71      0.70      0.70     45367
# weighted avg       0.71      0.70      0.70     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     89562
#            1       1.00      1.00      1.00     91905
#
#     accuracy                           1.00    181467
#    macro avg       1.00      1.00      1.00    181467
# weighted avg       1.00      1.00      1.00    181467

# %%
forest = RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=21)
forest.fit(tfidf_train, y_train)
tfidf_pred = forest.predict(tfidf_test)
print('test')
print(classification_report(y_test, tfidf_pred))
print('train')
print(classification_report(y_train, forest.predict(tfidf_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71     22361
#            1       0.72      0.73      0.72     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00     89562
#            1       1.00      1.00      1.00     91905
#
#     accuracy                           1.00    181467
#    macro avg       1.00      1.00      1.00    181467
# weighted avg       1.00      1.00      1.00    181467

# %%
#нет лимита глубины дерева как вероятная причина переобучения и времязатратности, на тестовой выборке приемлимо

# %%
df2 = pd.read_csv('clean_df2_no_solo.csv')
df2['text'] = df2['text'].apply(lambda x: x[2:-2].replace("', '", " "))
df2
# Out:
#                         id        date             name  \
# 0       408906692374446080  1386325927  pleease_shut_up
# 1       408906692693221377  1386325927  alinakirpicheva
# 2       408906695083954177  1386325927        EvgeshaRe
# 3       408906695356973056  1386325927    ikonnikova_21
# 4       408906761416867842  1386325943        JumpyAlex
# ...                    ...         ...              ...
# 226829  425138243257253888  1390195830         Yanch_96
# 226830  425138339503943682  1390195853          tkit_on
# 226831  425138437684215808  1390195876         ckooker1
# 226832  425138490452344832  1390195889       LisaBeroud
# 226833  425138595251625984  1390195914       sukapavlov
#
#                                                      text  positive  rep  rtv  \
# 0              школотый поверь самый общество предмет тип         1    0    0
# 1                      таки немного похожий мальчик равно         1    0    0
# 2                                      идиотка испугаться         1    0    1
# 3       угол сидеть погибать голод ещ порция взять хот...         1    0    1
# 4       значит страшилка блин посмотреть часть создать...         1    0    0
# ...                                                   ...       ...  ...  ...
# 226829                           каждый хотеть исправлять         0    0    0
# 226830               скучать вправлять мозг равно скучать         0    0    0
# 226831                               школа говно это идти         0    0    0
# 226832                             тауриэль грусть обнять         0    0    1
# 226833  такси везти работа раздумывать втащить пятый э...         0    0    0
#
#         fav  total_count  fol  friends  list_count
# 0         0         7569   62       61           0
# 1         0        11825   59       31           2
# 2         0         1273   26       27           0
# 3         0         1549   19       17           0
# 4         0          597   16       23           1
# ...     ...          ...  ...      ...         ...
# 226829    0         1138   32       46           0
# 226830    0         4822   38       32           0
# 226831    1          165   13       16           0
# 226832    0         2516  187      265           0
# 226833    0         7778  146       66           5
#
# [226834 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df2.text, df2.positive, test_size=0.2, random_state=21)

# %%
cv = CountVectorizer()
cv_train = cv.fit_transform(X_train)
cv_test = cv.transform(X_test)

tfidf = TfidfVectorizer()
tfidf_train = tfidf.fit_transform(X_train)
tfidf_test = tfidf.transform(X_test)

# %%
lr = LogisticRegression(random_state=21)
lr.fit(cv_train, y_train)
cv_pred = lr.predict(cv_test)
print('test')
print(classification_report(y_test, cv_pred))
print('train')
print(classification_report(y_train, lr.predict(cv_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71     22361
#            1       0.72      0.73      0.72     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79     89562
#            1       0.79      0.80      0.80     91905
#
#     accuracy                           0.79    181467
#    macro avg       0.79      0.79      0.79    181467
# weighted avg       0.79      0.79      0.79    181467

# %%
lr = LogisticRegression(random_state=21)
lr.fit(tfidf_train, y_train)
tfidf_pred = lr.predict(tfidf_test)
print('test')
print(classification_report(y_test, tfidf_pred))
print('train')
print(classification_report(y_train, lr.predict(tfidf_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.73      0.69      0.71     22361
#            1       0.71      0.75      0.73     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77     89562
#            1       0.77      0.80      0.78     91905
#
#     accuracy                           0.78    181467
#    macro avg       0.78      0.78      0.78    181467
# weighted avg       0.78      0.78      0.78    181467

# %%
forest = RandomForestClassifier(n_estimators=200, max_depth=100, n_jobs=-1, random_state=21)
forest.fit(cv_train, y_train)
cv_pred = forest.predict(cv_test)
print('test')
print(classification_report(y_test, cv_pred))
print('train')
print(classification_report(y_train, forest.predict(cv_train)))
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.75      0.57      0.65     22361
#            1       0.66      0.81      0.73     23006
#
#     accuracy                           0.69     45367
#    macro avg       0.70      0.69      0.69     45367
# weighted avg       0.70      0.69      0.69     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75     89562
#            1       0.73      0.91      0.81     91905
#
#     accuracy                           0.78    181467
#    macro avg       0.80      0.78      0.78    181467
# weighted avg       0.80      0.78      0.78    181467

# %%
import time

# %%
depth = [10, 50, 100, 150, 200, None]
for dep in depth:
    start = time.time()
    forest = (n_estimators=200, max_depth=dep, n_jobs=-1, random_state=21)
    forest.fit(tfidf_train, y_train)
    tfidf_pred = forest.predict(tfidf_test)
    print('test')
    print(classification_report(y_test, tfidf_pred))
    print('train')
    print(classification_report(y_train, forest.predict(tfidf_train)))
    print("executing time: ", time.time() - start)
    print("----------------------------------------------------")
# Out:
# test
#               precision    recall  f1-score   support
#
#            0       0.79      0.34      0.48     22361
#            1       0.59      0.91      0.71     23006
#
#     accuracy                           0.63     45367
#    macro avg       0.69      0.63      0.60     45367
# weighted avg       0.69      0.63      0.60     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.81      0.36      0.50     89562
#            1       0.59      0.92      0.72     91905
#
#     accuracy                           0.64    181467
#    macro avg       0.70      0.64      0.61    181467
# weighted avg       0.70      0.64      0.61    181467
#
# executing time:  3.838513135910034
# ----------------------------------------------------
# test
#               precision    recall  f1-score   support
#
#            0       0.75      0.52      0.62     22361
#            1       0.64      0.83      0.72     23006
#
#     accuracy                           0.68     45367
#    macro avg       0.70      0.68      0.67     45367
# weighted avg       0.70      0.68      0.67     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.83      0.56      0.67     89562
#            1       0.67      0.89      0.77     91905
#
#     accuracy                           0.73    181467
#    macro avg       0.75      0.72      0.72    181467
# weighted avg       0.75      0.73      0.72    181467
#
# executing time:  21.23353600502014
# ----------------------------------------------------
# test
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64     22361
#            1       0.66      0.81      0.73     23006
#
#     accuracy                           0.69     45367
#    macro avg       0.70      0.69      0.69     45367
# weighted avg       0.70      0.69      0.69     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.89      0.65      0.75     89562
#            1       0.73      0.92      0.81     91905
#
#     accuracy                           0.78    181467
#    macro avg       0.81      0.78      0.78    181467
# weighted avg       0.81      0.78      0.78    181467
#
# executing time:  68.38034892082214
# ----------------------------------------------------
# test
#               precision    recall  f1-score   support
#
#            0       0.75      0.58      0.66     22361
#            1       0.67      0.81      0.73     23006
#
#     accuracy                           0.70     45367
#    macro avg       0.71      0.70      0.69     45367
# weighted avg       0.71      0.70      0.69     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80     89562
#            1       0.76      0.95      0.85     91905
#
#     accuracy                           0.83    181467
#    macro avg       0.85      0.83      0.82    181467
# weighted avg       0.85      0.83      0.82    181467
#
# executing time:  128.5330958366394
# ----------------------------------------------------
# test
#               precision    recall  f1-score   support
#
#            0       0.74      0.60      0.66     22361
#            1       0.67      0.80      0.73     23006
#
#     accuracy                           0.70     45367
#    macro avg       0.71      0.70      0.70     45367
# weighted avg       0.71      0.70      0.70     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.96      0.74      0.84     89562
#            1       0.80      0.97      0.87     91905
#
#     accuracy                           0.86    181467
#    macro avg       0.88      0.86      0.86    181467
# weighted avg       0.88      0.86      0.86    181467
#
# executing time:  199.14020776748657
# ----------------------------------------------------
# test
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71     22361
#            1       0.72      0.74      0.73     23006
#
#     accuracy                           0.72     45367
#    macro avg       0.72      0.72      0.72     45367
# weighted avg       0.72      0.72      0.72     45367
#
# train
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99     89562
#            1       1.00      0.99      0.99     91905
#
#     accuracy                           0.99    181467
#    macro avg       0.99      0.99      0.99    181467
# weighted avg       0.99      0.99      0.99    181467
#
# executing time:  812.6381089687347
# ----------------------------------------------------
